# %%
# %pip install xgboost mlflow

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append(os.path.abspath("./src"))

from medallion_utils import load_config, ingest_bronze, process_silver, process_gold
from train_xgboost import run_training

config = load_config("./config/config.yaml")

# %%
print("=== Ingesting Bronze... ===")
ingest_bronze(spark, config)

print("\n=== Processing Silver... ===")
process_silver(spark, config)

print("\n=== Processing Gold... ===")
process_gold(spark, config)

print("\n=== Training Model... ===")
run_training(spark, config)
