# %%
import yaml

with open("../conf/base_config.yaml", "r") as f:
    config = yaml.safe_load(f)

print("Configuração carregada com sucesso!")
print(f"Tabela Silver será: {config['paths']['silver']}")
